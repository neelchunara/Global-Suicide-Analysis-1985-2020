# %%
import pandas as pd
from pathlib import Path
import json

# %%
csv_file = Path("Resources/cleaned_sucide.csv")
sucide_data = pd.read_csv(csv_file)

sucide_data
# Out:
#                         country  year     sex          age  sucides_100k_pop  \
# 0                       Albania  1987    male  15-24 years          6.710000
# 1                       Albania  1987    male  35-54 years          5.190000
# 2                       Albania  1987  female  15-24 years          4.830000
# 3                       Albania  1987    male    75+ years          4.590000
# 4                       Albania  1987    male  25-34 years          3.280000
# ...                         ...   ...     ...          ...               ...
# 31751                   Ukraine  2017  female    75+ years          0.571032
# 31752            United Kingdom  2017  female    75+ years          0.157435
# 31753  United States of America  2017  female    75+ years          0.154096
# 31754                   Uruguay  2017  female    75+ years          0.409094
# 31755                Uzbekistan  2017  female    75+ years          0.009263
#
#        gdp_per_capita
# ...

# %%
# Convert DataFrame to JSON
json_data = sucide_data.to_json(orient='records', indent=4)

# Write the JSON data to a file
json_file = "sucide.json"
with open(json_file, 'w') as f:
    f.write(json_data)
